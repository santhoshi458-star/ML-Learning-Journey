# %%
import os
print(os.getcwd())
# Out:
# C:\JN\GenAI

# %%
#from scraper import fetch_website_contents
from openai import OpenAI

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

# Load environment variables
load_dotenv()

# Initialize client with API key
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %%
#messages
message="Hello GPT! this is my first ever message to you"
messages={'role':'user','content':message}
messages
# Out:
# {'role': 'user', 'content': 'Hello GPT! this is my first ever message to you'}

# %%
openai=OpenAI()

# %%
messages = [ {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": "Explain the difference between supervised and unsupervised learning."} ]

response=openai.chat.completions.create(model="gpt-5-nano",messages=messages)
response.choices[0].message.content
# Out:
# 'Here’s a clear contrast between supervised and unsupervised learning.\n\n- Supervised learning\n  - Data: Uses labeled data (inputs X paired with target outputs y).\n  - Objective: Learn a function f(X) that maps inputs to the correct outputs.\n  - Tasks: Classification (discrete labels) and regression (continuous targets).\n  - Common algorithms: Linear/logistic regression, support vector machines, decision trees, random forests, gradient boosting, neural networks.\n  - Evaluation: Measured against true labels using metrics like accuracy, precision/recall, F1, RMSE, MAE, AUC, etc. Typically split into train/validation/test sets.\n  - Examples: Predicting house prices from features, spam detection, image recognition with labeled objects.\n  - When to use: You have reliable labeled data and a specific prediction target you want to estimate.\n\n- Unsupervised learning\n  - Data: Uses unlabeled data (only inputs X, no y).\n  - Objective: Discover structure, patterns, or representations in the data.\n  - Tasks: Clustering, dimensionality reduction, density estimation, anomaly detection, association rule learning.\n  - Common algorithms: K-means, hierarchical clustering, PCA, t-SNE, DBSCAN, autoencoders, Gaussian mixture models.\n  - Evaluation: More intrinsic metrics (e.g., silhouette score, inertia/WSS, reconstruction error) or qualitative assessments; sometimes usefulness is judged by downstream tasks.\n  - Examples: Grouping customers into segments, reducing data dimensionality for visualization, finding unusual transactions.\n  - When to use: You don’t have labeled targets but want to explore structure, compress data, or prepare features for supervised tasks.\n\n- Notes and hybrids\n  - Semi-supervised learning uses a small amount of labeled data with a large amount of unlabeled data.\n  - Sometimes unsupervised learning is used to pretrain representations for supervised tasks (feature learning).\n  - Reinforcement learning (not covered above) involves learning by interacting with an environment to maximize cumulative reward.\n\nIf you tell me your data and goal, I can suggest which approach fits best and outline a workflow.'

# %%
messages = [ {"role": "system", "content": "You are a funny assistant."},
            {"role": "user", "content": "what is 2+2 ?"} ]

response=openai.chat.completions.create(model="gpt-4.1-nano",messages=messages)
response.choices[0].message.content
# Out:
# 'Well, if we\'re talking about the classic math problem, 2 + 2 equals 4. But if you\'re asking me what 2 + 2 is in the universe of humor, I might suggest it\'s "2 + 2," which sounds like the start of a dad joke waiting to happen!'

# %%
system_prompt = """
You are a snarky assistant that analyzes the contents of a website,
and provides a short, snarky, humorous summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""
user_prompt_prefix = """
Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.

"""

# %%
#fetch website content
def messages_for(website):
    return[{"role":"system","content":system_prompt},
           {"role":"user","content":user_prompt_prefix+website}]

# %%
#readwebsite
from bs4 import BeautifulSoup
import requests

# Standard headers to fetch a website
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}
def fetch_website_contents(url):
    """
    Return the title and contents of the website at the given url;
    truncate to 2,000 characters as a sensible limit
    """
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.content, "html.parser")
    title = soup.title.string if soup.title else "No title found"
    if soup.body:
        for irrelevant in soup.body(["script", "style", "img", "input"]):
            irrelevant.decompose()
        text = soup.body.get_text(separator="\n", strip=True)
    else:
        text = ""
    return (title + "\n\n" + text)[:2_000]

# %%
ed="https://myknowtech.com/"
messages_for(ed)
# Out:
# [{'role': 'system',
#   'content': '\nYou are a snarky assistant that analyzes the contents of a website,\nand provides a short, snarky, humorous summary, ignoring text that might be navigation related.\nRespond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.\n'},
#  {'role': 'user',
#   'content': '\nHere are the contents of a website.\nProvide a short summary of this website.\nIf it includes news or announcements, then summarize these too.\n\nhttps://myknowtech.com/'}]

# %%
def summarize(url):
    website=fetch_website_contents(url)
    response=openai.chat.completions.create(model="gpt-4.1-mini",messages=messages_for(website))
    return response.choices[0].message.content

# %%
summarize("https://myknowtech.com/")
# Out:
# "# MyKnowTech: The Pega Whisperers You Didn't Know You Needed\n\nSo, you’re stuck wrestling with your Pega systems—Constellation migrations giving you nightmares, security risks lurking in every corner, and your Center of Excellence (COE) about as stable as a Jenga tower on a windy day? Enter MyKnowTech, a boutique Pega consulting company that promises to untangle your Pega mess with tailor-made solutions, expert enablement, and modernization services.\n\nThey’re basically the Pega-savvy heroes with empathy, ownership, and enough tech wizardry to make your legacy systems feel young again. Whether you want to speed up your digital transformation or just stop stressing about your Pega stack, they’ve got ready-to-deploy frameworks and customizable services lined up.\n\nTL;DR: If your Pega life feels like a soap opera, MyKnowTech is the premium consulting cast here to fix the drama with brains and a sprinkle of empathy. No breaking news, just breaking down your Pega problems one solution at a time."

# %%
summarize("https://www.udemy.com/")
# Out:
# 'Ah, the classic "Enable JavaScript and cookies" roadblock—because nothing says "welcome" like a digital bouncer demanding your browser obey its every whim before you can even see what\'s inside. Spoiler alert: I can\'t summarize what I can\'t see, so enjoy toggling those settings!'
