# %%
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown,display,update_display
import ollama

# %%
MODEL_GPT = 'gpt-4o-mini'
MODEL_LLAMA = 'llama3.2'

# %%
load_dotenv()
openai = OpenAI()

# %%
question="""print("welcome to LLM")"""

# %%
system_prompt="You are a helpful technical tutor who answers the questions about python code,Data science and LLM"
user_prompt="Please give detail explanation about the question:"+question

# %%
response=openai.chat.completions.create(model=MODEL_GPT,messages=[{"role":"system","content":system_prompt},
                                                                  {"role":"user","content":user_prompt}])
result=display(Markdown(response.choices[0].message.content))
# Out:
# The line of code you provided is written in Python, a widely used programming language. Let's break down the components of the statement `print("welcome to LLM")`:
#
# 1. **Function**:
#    - `print()` is a built-in Python function that outputs data to the console or standard output device. It is one of the fundamental functions you'll use for displaying information while you're developing or debugging your code.
#
# 2. **Arguments**:
#    - Inside the parentheses, you see `"welcome to LLM"`. This is a string, which in Python is a sequence of characters enclosed in either single quotes (`'`) or double quotes (`"`). Both are acceptable in Python; the choice between them often depends on style preferences or the need to include one type of quote within the other (for example, to avoid escaping).
#
# 3. **String**:
# ...

# %%
messages=[{"role":"system","content":system_prompt},
          {"role":"user","content":user_prompt}]

# %%
stream = openai.chat.completions.create(model=MODEL_GPT, messages=messages,stream=True)
    
response = ""
display_handle = display(Markdown(""), display_id=True)
for chunk in stream:
    response += chunk.choices[0].delta.content or ''
    response = response.replace("```","").replace("markdown", "")
    update_display(Markdown(response), display_id=display_handle.display_id)
# Out:
# The line of code `print("welcome to LLM")` is a simple example of a Python statement that outputs text to the console. Let's break it down into its components:
#
# ### 1. `print()` Function:
# - `print()` is a built-in function in Python used to display output to the standard output device (usually the console or terminal).
# - It can take one or more arguments, which can be strings, numbers, or other data types, and it will convert them into a string format (if necessary) before displaying.
#
# ### 2. Argument:
# - Inside the parentheses of the `print()` function, we have the argument `"welcome to LLM"`.
# - The argument is a string literal, which is a sequence of characters enclosed in quotes (in this case, double quotes). You can also use single quotes for string literals in Python, e.g., `'welcome to LLM'`.
#
# ### 3. Output:
# - When `print("welcome to LLM")` is executed, it produces the output:
#
#   welcome to LLM
#
# ...

# %%
response = ollama.chat(model=MODEL_LLAMA, messages=messages)
reply = response['message']['content']
display(Markdown(reply))
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 response = ollama.chat(model=MODEL_LLAMA, messages=messages)
#       2 reply = response['message']['content']
#       3 display(Markdown(reply))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ollama\_client.py:365, in Client.chat(self, model, messages, tools, stream, think, logprobs, top_logprobs, format, options, keep_alive)
#     318 def chat(
#     319   self,
#     320   model: str = '',
#    (...)
#     330   keep_alive: Optional[Union[float, str]] = None,
#     331 ) -> Union[ChatResponse, Iterator[ChatResponse]]:
#     332   """
#     333   Create a chat response using the requested model.
#     334
#    (...)
#     363   Returns `ChatResponse` if `stream` is `False`, otherwise returns a `ChatResponse` generator.
#     364   """
# --> 365   return self._request(
# ...
