# %% [markdown]
# # __Demo: Creating a Custom Template__

# %% [markdown]
# ## __Steps to Perform__
# Step 1: Set up the Environment
#
# Step 2: Define the Prompt Template
#
# Step 3: Create a Custom Prompt Template Class

# %% [markdown]
# ### __Step 1: Set up the Environment__
#
# - Import required modules such as StringPromptTemplate from the langchain.prompts library and BaseModel and validator from Pydantic library.

# %%
pip uninstall torch torchvision torchaudio

# %%
from langchain_core.prompts import PromptTemplate

prompt = PromptTemplate(
    input_variables=["product"],
    template="What is a good name for a company that makes {product}?"
)

print(prompt.format(product="AI tools"))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from langchain_core.prompts import PromptTemplate
#       3 prompt = PromptTemplate(
#       4     input_variables=["product"],
#       5     template="What is a good name for a company that makes {product}?"
#       6 )
#       8 print(prompt.format(product="AI tools"))
#
# File <frozen importlib._bootstrap>:1412, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_core\prompts\__init__.py:95, in __getattr__(attr_name)
#      93 def __getattr__(attr_name: str) -> object:
#      94     module_name = _dynamic_imports.get(attr_name)
# ---> 95     result = import_attr(attr_name, module_name, __spec__.parent)
#      96     globals()[attr_name] = result
#      97     return result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_core\_import_utils.py:35, in import_attr(attr_name, module_name, package)
#      33 else:
#      34     try:
# ---> 35         module = import_module(f".{module_name}", package=package)
#      36     except ModuleNotFoundError as err:
#      37         msg = f"module '{package!r}.{module_name!r}' not found ({err})"
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\importlib\__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_core\prompts\prompt.py:11
#       8 from pydantic import BaseModel, model_validator
#       9 from typing_extensions import override
# ---> 11 from langchain_core.prompts.string import (
#      12     DEFAULT_FORMATTER_MAPPING,
#      13     PromptTemplateFormat,
#      14     StringPromptTemplate,
#      15     check_valid_template,
#      16     get_template_variables,
#      17     mustache_schema,
#      18 )
#      20 if TYPE_CHECKING:
#      21     from langchain_core.runnables.config import RunnableConfig
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_core\prompts\string.py:13
#      10 from pydantic import BaseModel, create_model
#      12 from langchain_core.prompt_values import PromptValue, StringPromptValue
# ---> 13 from langchain_core.prompts.base import BasePromptTemplate
#      14 from langchain_core.utils import get_colored_text, mustache
#      15 from langchain_core.utils.formatting import formatter
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_core\prompts\base.py:25
#      23 from langchain_core.exceptions import ErrorCode, create_message
#      24 from langchain_core.load import dumpd
# ---> 25 from langchain_core.output_parsers.base import BaseOutputParser
#      26 from langchain_core.prompt_values import (
#      27     ChatPromptValueConcrete,
#      28     PromptValue,
#      29     StringPromptValue,
#      30 )
#      31 from langchain_core.runnables import RunnableConfig, RunnableSerializable
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_core\output_parsers\base.py:16
#       7 from typing import (
#       8     TYPE_CHECKING,
#       9     Any,
#      10     Generic,
#      11     TypeVar,
#      12 )
#      14 from typing_extensions import override
# ---> 16 from langchain_core.language_models import LanguageModelOutput
#      17 from langchain_core.messages import AnyMessage, BaseMessage
#      18 from langchain_core.outputs import ChatGeneration, Generation
#
# File <frozen importlib._bootstrap>:1412, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_core\language_models\__init__.py:110, in __getattr__(attr_name)
#     108 def __getattr__(attr_name: str) -> object:
#     109     module_name = _dynamic_imports.get(attr_name)
# --> 110     result = import_attr(attr_name, module_name, __spec__.parent)
#     111     globals()[attr_name] = result
#     112     return result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_core\_import_utils.py:35, in import_attr(attr_name, module_name, package)
#      33 else:
#      34     try:
# ---> 35         module = import_module(f".{module_name}", package=package)
#      36     except ModuleNotFoundError as err:
#      37         msg = f"module '{package!r}.{module_name!r}' not found ({err})"
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\importlib\__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_core\language_models\base.py:41
#      38     from langchain_core.outputs import LLMResult
#      40 try:
# ---> 41     from transformers import GPT2TokenizerFast  # type: ignore[import-not-found]
#      43     _HAS_TRANSFORMERS = True
#      44 except ImportError:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\__init__.py:27
#      24 from typing import TYPE_CHECKING
#      26 # Check the dependencies satisfy the minimal versions required.
# ---> 27 from . import dependency_versions_check
#      28 from .utils import (
#      29     OptionalDependencyNotAvailable,
#      30     _LazyModule,
#    (...)
#      36     is_pretty_midi_available,
#      37 )
#      39 # Note: the following symbols are deliberately exported with `as`
#      40 # so that mypy, pylint or other static linters can recognize them,
#      41 # given that they are not exported using `__all__` in this file.
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\dependency_versions_check.py:16
#       1 # Copyright 2020 The HuggingFace Team. All rights reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 from .dependency_versions_table import deps
# ---> 16 from .utils.versions import require_version, require_version_core
#      19 # define which module versions we always want to check at run time
#      20 # (usually the ones defined in `install_requires` in setup.py)
#      21 #
#      22 # order specific notes:
#      23 # - tqdm must be checked before tokenizers
#      25 pkgs_to_check_at_runtime = [
#      26     "python",
#      27     "tqdm",
#    (...)
#      37     "pyyaml",
#      38 ]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\utils\__init__.py:24
#      21 from packaging import version
#      23 from .. import __version__
# ---> 24 from .auto_docstring import (
#      25     ClassAttrs,
#      26     ClassDocstring,
#      27     ImageProcessorArgs,
#      28     ModelArgs,
#      29     ModelOutputArgs,
#      30     auto_class_docstring,
#      31     auto_docstring,
#      32     get_args_doc_from_source,
#      33     parse_docstring,
#      34     set_min_indent,
#      35 )
#      36 from .backbone_utils import BackboneConfigMixin, BackboneMixin
#      37 from .chat_template_utils import DocstringParsingException, TypeHintParsingException, get_json_schema
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\utils\auto_docstring.py:30
#      22 import regex as re
#      24 from .doc import (
#      25     MODELS_TO_PIPELINE,
#      26     PIPELINE_TASKS_TO_SAMPLE_DOCSTRINGS,
#      27     PT_SAMPLE_DOCSTRINGS,
#      28     _prepare_output_docstrings,
#      29 )
# ---> 30 from .generic import ModelOutput
#      33 PATH_TO_TRANSFORMERS = Path("src").resolve() / "transformers"
#      36 AUTODOC_FILES = [
#      37     "configuration_*.py",
#      38     "modeling_*.py",
#    (...)
#      43     "feature_extractor_*.py",
#      44 ]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\utils\generic.py:51
#      47 logger = logging.get_logger(__name__)
#      49 if is_torch_available():
#      50     # required for @can_return_tuple decorator to work with torchdynamo
# ---> 51     import torch
#      53     from ..model_debugging_utils import model_addition_debugger_context
#      56 # vendored from distutils.util
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\__init__.py:281
#     277                     raise err
#     279         kernel32.SetErrorMode(prev_error_mode)
# --> 281     _load_dll_libraries()
#     282     del _load_dll_libraries
#     285 def _get_cuda_dep_paths(path: str, lib_folder: str, lib_name: str) -> list[str]:
#     286     # Libraries can either be in
#     287     # path/nvidia/lib_folder/lib or
#     288     # path/nvidia/cuXX/lib (since CUDA 13.0) or
#     289     # path/lib_folder/lib
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\__init__.py:264, in _load_dll_libraries()
#     260     err = ctypes.WinError(last_error)
#     261     err.strerror += (
#     262         f' Error loading "{dll}" or one of its dependencies.'
#     263     )
# --> 264     raise err
#     265 elif res is not None:
#     266     is_loaded = True
#
# OSError: [WinError 1114] A dynamic link library (DLL) initialization routine failed. Error loading "C:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\lib\c10.dll" or one of its dependencies.

# %%
from langchain import PromptTemplate
from pydantic import BaseModel, field_validator
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from langchain import PromptTemplate
#       2 from pydantic import BaseModel, field_validator
#
# ImportError: cannot import name 'PromptTemplate' from 'langchain' (C:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain\__init__.py)

# %% [markdown]
# ### __Step 2: Define the Prompt Template__
# - Define a constant string PROMPT that outlines the structure of the prompt to be used for generating book summaries.
# - Include placeholders for dynamic content like the book title.

# %%
PROMPT = """\
Given the book title, generate a brief summary of the book.
Book Title: {book_title}
Summary:
"""

# %% [markdown]
# ### __Step 3: Create a Custom Prompt Template Class__
#
# - The custom class BookSummarizerPrompt is created, which does not inherit from __StringPromptTemplate__ as initially described.
# - It has a template field of type __StringPromptTemplate__. This class is responsible for integrating the prompt template with dynamic content (the book title) and is built on BaseModel from Pydantic to enable input validation.
# - The Config class within __BookSummarizerPrompt__ sets __arbitrary_types_allowed = True__, allowing for the inclusion of custom types like __StringPromptTemplate__ as a field in the Pydantic model.
# - A __create_prompt__ method is implemented to dynamically insert the book title into the prompt template.

# %%
from pydantic import BaseModel, validator

class StringPromptTemplate:
    def __init__(self, template):
        self.template = template

    def format(self, **kwargs):
        return self.template.format(**kwargs)

class BookSummarizerPrompt(BaseModel):
    book_title: str
    template: StringPromptTemplate

    class Config:
        arbitrary_types_allowed = True

    def create_prompt(self):
        return self.template.format(book_title=self.book_title)

# Assuming an instance of StringPromptTemplate is created elsewhere
template = StringPromptTemplate(
    """\
Given the book title, generate a brief summary of the book.
Book Title: {book_title}
Summary:
"""
)

# Usage
book_summarizer_prompt = BookSummarizerPrompt(book_title="The Great Gatsby", template=template)
print(book_summarizer_prompt.create_prompt())
# Out:
# Given the book title, generate a brief summary of the book.
# Book Title: The Great Gatsby
# Summary:

# %% [markdown]
# ## __Conclusion__
# This demo is designed to dynamically generate book summaries by inserting book titles into a structured prompt template.
#
# It achieves this through a custom implementation involving a template class for formatting and a Pydantic model for data validation and dynamic content integration, ensuring the output is tailored and accurate.
